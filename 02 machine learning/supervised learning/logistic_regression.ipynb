# %% [markdown]
# <a href="https://colab.research.google.com/github/mikeogunmakin/study/blob/main/03%20machine%20learning/supervised%20learning/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
